# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
df = pd.read_csv('../data/alt_fuel.csv')

# %%
df.columns = [c.lower() for c in df.columns]
df.columns = df.columns.str.replace(' ', '_')

# %%
df.head()
# Out:
#   fuel_type_code                                 station_name  \
# 0            CNG  Memphis Light, Gas and Water - North Center
# 1            LPG                             Blossman Gas Inc
# 2            LPG                             Blossman Gas Inc
# 3            LPG                                       U-Haul
# 4            LPG                                       U-Haul
#
#           street_address                            intersection_directions  \
# 0         1130 Tupelo St                                                NaN
# 1      1121 Highway 19 E  At Highway 37 E Bypass, 1 mile south of inters...
# 2            2798 APD 40                                     Off Highway 64
# 3   121 Moving Center Ct                                        Gallatin Rd
# 4  1420 NE Memorial Blvd                                           At Clark
#
#            city state    zip  plus4               station_phone status_code  \
# 0       Memphis    TN  38108    NaN  901-320-1062  901-320-1473           E
# 1  Elizabethton    TN  37643    NaN                423-542-3511           E
# 2     Cleveland    TN  37323    NaN                423-479-7569           E
# 3       Madison    TN  37115    NaN                615-868-5081           E
# 4  Murfreesboro    TN  37129    NaN                615-896-9018           E
#
#    ... ev_pricing_(french)           lpg_nozzle_types hydrogen_pressures  \
# 0  ...                 NaN                        NaN                NaN
# 1  ...                 NaN  ["ACME", "QUICK_CONNECT"]                NaN
# 2  ...                 NaN  ["ACME", "QUICK_CONNECT"]                NaN
# 3  ...                 NaN  ["QUICK_CONNECT", "ACME"]                NaN
# 4  ...                 NaN  ["QUICK_CONNECT", "ACME"]                NaN
#
#   hydrogen_standards cng_fill_type_code cng_psi  cng_vehicle_class  \
# 0                NaN                  Q  3600.0                 HD
# 1                NaN                NaN     NaN                NaN
# 2                NaN                NaN     NaN                NaN
# 3                NaN                NaN     NaN                NaN
# 4                NaN                NaN     NaN                NaN
#
#    lng_vehicle_class  ev_on-site_renewable_source  restricted_access
# 0                NaN                          NaN                NaN
# 1                NaN                          NaN                NaN
# 2                NaN                          NaN                NaN
# 3                NaN                          NaN                NaN
# 4                NaN                          NaN                NaN
#
# [5 rows x 65 columns]

# %%
df_elec = df.loc[df['fuel_type_code'] == 'ELEC']

# %%
df_elec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 688 entries, 40 to 871
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   fuel_type_code                    688 non-null    object
#  1   station_name                      688 non-null    object
#  2   street_address                    687 non-null    object
#  3   intersection_directions           41 non-null     object
#  4   city                              688 non-null    object
#  5   state                             688 non-null    object
#  6   zip                               688 non-null    int64
#  7   plus4                             0 non-null      float64
#  8   station_phone                     626 non-null    object
#  9   status_code                       688 non-null    object
#  10  expected_date                     1 non-null      object
#  11  groups_with_access_code           688 non-null    object
#  12  access_days_time                  628 non-null    object
#  13  cards_accepted                    14 non-null     object
#  14  bd_blends                         0 non-null      object
#  15  ng_fill_type_code                 0 non-null      object
#  16  ng_psi                            0 non-null      float64
#  17  ev_level1_evse_num                11 non-null     float64
#  18  ev_level2_evse_num                629 non-null    float64
#  19  ev_dc_fast_count                  71 non-null     float64
#  20  ev_other_info                     0 non-null      float64
#  21  ev_network                        688 non-null    object
#  22  ev_network_web                    518 non-null    object
#  23  geocode_status                    688 non-null    object
#  24  latitude                          688 non-null    float64
#  25  longitude                         688 non-null    float64
#  26  date_last_confirmed               688 non-null    object
#  27  id                                688 non-null    int64
#  28  updated_at                        688 non-null    object
#  29  owner_type_code                   242 non-null    object
#  30  federal_agency_id                 40 non-null     float64
#  31  federal_agency_name               40 non-null     object
#  32  open_date                         688 non-null    object
#  33  hydrogen_status_link              0 non-null      float64
#  34  ng_vehicle_class                  0 non-null      object
#  35  lpg_primary                       0 non-null      object
#  36  e85_blender_pump                  0 non-null      object
#  37  ev_connector_types                687 non-null    object
#  38  country                           688 non-null    object
#  39  intersection_directions_(french)  0 non-null      float64
#  40  access_days_time_(french)         0 non-null      float64
#  41  bd_blends_(french)                0 non-null      float64
#  42  groups_with_access_code_(french)  688 non-null    object
#  43  hydrogen_is_retail                0 non-null      float64
#  44  access_code                       688 non-null    object
#  45  access_detail_code                69 non-null     object
#  46  federal_agency_code               40 non-null     object
#  47  facility_type                     225 non-null    object
#  48  cng_dispenser_num                 0 non-null      float64
#  49  cng_on-site_renewable_source      0 non-null      object
#  50  cng_total_compression_capacity    0 non-null      float64
#  51  cng_storage_capacity              0 non-null      float64
#  52  lng_on-site_renewable_source      0 non-null      object
#  53  e85_other_ethanol_blends          0 non-null      object
#  54  ev_pricing                        301 non-null    object
#  55  ev_pricing_(french)               0 non-null      float64
#  56  lpg_nozzle_types                  0 non-null      object
#  57  hydrogen_pressures                0 non-null      float64
#  58  hydrogen_standards                0 non-null      float64
#  59  cng_fill_type_code                0 non-null      object
#  60  cng_psi                           0 non-null      float64
#  61  cng_vehicle_class                 0 non-null      object
#  62  lng_vehicle_class                 0 non-null      object
#  63  ev_on-site_renewable_source       10 non-null     object
#  64  restricted_access                 0 non-null      float64
# dtypes: float64(22), int64(2), object(41)
# memory usage: 354.8+ KB

# %%
df_elec.head()
# Out:
#    fuel_type_code                     station_name        street_address  \
# 40           ELEC  METRO NASHVILLE FULTON GARAGE 1  800 2nd Avenue South
# 53           ELEC                 Oak Ridge Nissan    101 S Illinois Ave
# 54           ELEC              Newton Nissan South    2801 Highway 231 N
# 55           ELEC             Mountain View Nissan      2100 S Market St
# 56           ELEC            Harold Mathews Nissan        185 Highway 76
#
#    intersection_directions         city state    zip  plus4 station_phone  \
# 40                     NaN    Nashville    TN  37210    NaN  888-758-4389
# 53                     NaN    Oak Ridge    TN  37830    NaN  865-482-5489
# 54                     NaN  Shelbyville    TN  37160    NaN  931-684-6811
# 55                     NaN  Chattanooga    TN  37408    NaN  423-756-1500
# 56                     NaN  Clarksville    TN  37043    NaN  931-552-7555
#
#    status_code  ... ev_pricing_(french) lpg_nozzle_types hydrogen_pressures  \
# 40           E  ...                 NaN              NaN                NaN
# 53           E  ...                 NaN              NaN                NaN
# 54           E  ...                 NaN              NaN                NaN
# 55           E  ...                 NaN              NaN                NaN
# 56           E  ...                 NaN              NaN                NaN
#
#    hydrogen_standards cng_fill_type_code cng_psi  cng_vehicle_class  \
# 40                NaN                NaN     NaN                NaN
# 53                NaN                NaN     NaN                NaN
# 54                NaN                NaN     NaN                NaN
# 55                NaN                NaN     NaN                NaN
# 56                NaN                NaN     NaN                NaN
#
#     lng_vehicle_class  ev_on-site_renewable_source  restricted_access
# 40                NaN                          NaN                NaN
# 53                NaN                          NaN                NaN
# 54                NaN                          NaN                NaN
# 55                NaN                          NaN                NaN
# 56                NaN                          NaN                NaN
#
# [5 rows x 65 columns]
